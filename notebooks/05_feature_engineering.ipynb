# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/processed/gurgaon_properties_cleaned_1.csv')
df.sample(5)
# Out:
#                    society property_type      sector  price(cr)  \
# 308             SS Almeria          flat   sector 84       1.48
# 2186        DLF The Arbour          flat   sector 63       7.80
# 3211           Independent         house   sector 13       4.50
# 2481   Smart World Orchard          flat   sector 61       1.47
# 1413  Emaar Gurgaon Greens          flat  sector 102       1.45
#
#       price_per_sqft    Area  \
# 308           7400.0  2000.0
# 2186         19747.0  3950.0
# 3211          9091.0  4950.0
# 2481         12782.0  1150.0
# 1413          8787.0  1650.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 308   Super Built up area 2000(185.81 sq.m.)Carpet a...        3         3
# 2186                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 3211                        Plot area 550(459.87 sq.m.)        4         5
# 2481                   Carpet area: 1150 (106.84 sq.m.)        2         2
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(121)

# %% [markdown]
# 1. areaWithType
