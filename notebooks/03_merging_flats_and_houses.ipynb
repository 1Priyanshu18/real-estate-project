# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('../data/processed/flats_cleaned.csv')
houses = pd.read_csv('../data/processed/house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df.sample(5)
# Out:
#                                       property_name                   society  \
# 3900  5 Bedroom House for sale in Sector 33 Gurgaon  Unitech Uniworld Resorts
# 1043                      4 BHK Flat in DLF Phase 5              DLF The Icon
# 2776               4 BHK Flat in Sector 109 Gurgaon         Chintels Paradiso
# 2964                3 BHK Flat in Sector 43 Gurgaon      Sanskriti Apartments
# 1608                3 BHK Flat in Sector 49 Gurgaon             Orchid Petals
#
#      property_type  price(cr)  price_per_sqft    Area  \
# 3900         house        8.5         17820.0  4770.0
# 1043          flat        6.0         26086.0  2300.0
# 2776          flat        2.0          7604.0  2630.0
# 2964          flat        2.5         13513.0  1850.0
# 1608          flat        1.9         10526.0  1805.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 3900             Plot area 530(443.15 sq.m.)        5         5      3+
# ...

# %%
df.to_csv('../data/processed/gurgaon_properties.csv',index=False)
